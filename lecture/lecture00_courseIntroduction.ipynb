# %% [markdown]
# <h1 align="center">《海洋数据分析》课程简介</h1>

# %% [markdown]
# ## 联系方式
# <strong>陈笔澄(任课老师)</strong><br>
# 办公室: 希平楼C3-322<br>
# 联系方式: 13810365751<br>
# 邮箱: bchen@xmu.edu.cn<br>
# <br>
#
# <strong>黄嘉豪(助教)</strong><br>
# 办公室: 希平楼C3-305<br>
# 邮箱: 22320221151447@stu.xmu.edu.cn<br>
# <br>
#
# 班级群微信(9月23日前有效)：<br>
# ![微信图片_20220916054455.jpg](attachment:8f242ce1-a835-4cf2-b5e6-96de45813617.jpg)

# %% [markdown]
# ## 课程计划

# %% [markdown]
# 周|日期|内容
# :----|:----|:----:
# 1|2022.09.16|课程简介+Python及其使用环境简介<br>
# 2-3|2022.09.23-2022.9.30|Python基础(注释、数据类型、变量、运算符、输入输出)<br>
# 5-6|2022.10.14-2022.10.21|Python控制体（if、for、while）<br>
# 7-8|2022.10.28-2022.11.04|Python函数+Python数组: numpy<br>
# 9|2022.11.11|期中考试
# 10-11|2022.11.18-2022.11.25|Python常用工具包与可视化: matplotlib、scipy、pandas<br>
# 12-15|2022.12.02-2022.12.30|Python进阶--数据处理与分析：地图绘制、成果展示、统计方法、时频分析<br>
# 16|2022.12.30|期末考试

# %% [markdown]
# ## 成绩构成
# - 考勤 5%
# - 作业
#     - 课后练习 20%
#     - 项目 40%
# - 期中考 15%
# - 期末考 20%
# - <strong>评分标准取决于: </strong>
#     1. 程序是否有相应注释说明
#     2. 程序是否能运行
#     3. 程序是否运行正确

# %% [markdown]
# ## 课程资源
# - <strong>课程资料</strong>: <a href="https://172.19.251.187:8341/"> https://172.19.251.187:8341/</a>
# - 软件安装: <a href="https://www.anaconda.com/"> https://www.anaconda.com/</a>
# - Python主页: <a href="https://www.python.org/"> https://www.python.org/ </a>
# - Jupyter主页: <a href="https://jupyter.org/"> https://jupyter.org/ </a>
# - 一个有趣的Linux学习网站: <a href="http://cn.linux.vbird.org/linux_basic/linux_basic.php">http://cn.linux.vbird.org/linux_basic/linux_basic.php</a>

# %% [markdown]
# ## 课程资料服务器登陆说明
# 1. 在浏览器中输入对应ip地址(<a href="https://172.19.251.187:8341/"> https://172.19.251.187:8341/</a>)
#     - 如果遇到风险提示，请继续登陆
# 2. 进入登陆界面
# ![image.png](attachment:image.png)
#     - 用户名为名字<strong>第一个字</strong>及<strong>最后一个字</strong>拼音首字母+学号后三位
#         - 例如，姓名<strong>陈笔澄</strong>，学号<strong>XXX123</strong>，用户名即为cc123
#     - 初次登陆输入的密码即为以后的登陆密码，<strong>请谨慎保管</strong>

# %% [markdown]
# ## 课后交流
# - 答疑时间: 周一/周四 14:00-16:00 (希平楼 C3-322) <br>
# - <strong>上机时间: 周二 19:00-21:00</strong> (暂定 希平楼 C3-311)
#     - <strong>非强制，但建议如无特殊情况请尽量参加(能在同学间相互讨论且有老师和助教答疑下完成作业，何乐而不为)<strong>

# %% [markdown]
# ## 一些建议
# - <strong>尽量参加上机练习</strong>
# - 多练习
# - 多使用搜索工具
# - 增加自主性
